# %%
import svd
import lowrank
import numpy as np

import scipy.misc
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
svd.z2and3()

# %%
svd.z4() # max(Ei) / min (Ei) > 100

# %% [markdown]
# | Shape | Color |
# | ---------------|-----|
# | $S$ | orange |
# | $SV_i^T$ | green |
# | $SΣ_iV_i^T$ | blue |
# | $SU_iΣ_iV_i^T$ | red |

# %%
svd.z5()

# %% [markdown]
# # Oryginał i kolejne kompresje

# %%
plt.imshow(scipy.misc.face(gray=True))
plt.show() # 768 x 1024

# %%
lowrank.z1(5) # k = 512

# %%
lowrank.z1(4) # k = 256

# %%
lowrank.z1(3) # k = 128

# %%
lowrank.z1(2) # k = 64

# %%
lowrank.z1(1) # k = 32

# %%
lowrank.z1(0) # k = 8

# %% [markdown]
# # Wizualizacja różnicy między orginałem a kolejnymi kompresjami

# %%
lowrank.z2(0)

# %%
lowrank.z2(1)

# %%
lowrank.z2(2)

# %%
lowrank.z2(3)

# %%
lowrank.z2(4)

# %%
lowrank.z2(5)
